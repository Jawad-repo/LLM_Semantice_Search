# %% [markdown]
# <a href="https://colab.research.google.com/github/Jawad-repo/LLM_Semantice_Search/blob/main/AI_FakeNewsDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Get the dataset from git repo

url_data = (r'https://raw.githubusercontent.com/Jawad-repo/Model_Training_Multilingual_Fake_News_Detection/main/Combined.csv')
df = pd.read_csv(url_data)

# %%
df_TrueFakeNews = df
df_TrueFakeNews.head(15)
# Out:
#    Sr_No.                                         News_Items Label
# 0       1  ٹی ٹی پی نے پنجاب حکومت کے ہیلی کاپٹر کے عملے ...  FAKE
# 1       2          مارک زکربرگ سیاست میں آنے کا سوچ رہے ہیں۔  FAKE
# 2       3     فریدہ جلال نے اپنی موت کی افواہوں پر تنقید کی۔  FAKE
# 3       4  جعلی خبریں: پاپ اسٹار حدیقہ کیانی نے جعلی منشی...  FAKE
# 4       5  صنم ماروی نے میڈیا پر گردش کرنے والی زیادتی او...  FAKE
# 5       6  نواز شریف نے واقعی کرپشن کی وجہ سے ڈیووس میں ت...  FAKE
# 6       7  پی ایف اے کی ’آئرن لیڈی‘ عائشہ ممتاز کا ویڈیو-...  FAKE
# 7       8                   CPEC  کے بارے میں خطرناک افواہیں  FAKE
# 8       9  امریکہ نے القاعدہ کی جعلی ویڈیوز بنانے پر کروڑ...  FAKE
# 9      10  پاکستان کا جعلی پروگرام نشر کرنے پر بھارتی چین...  FAKE
# 10     11  بھارتی صحافی نے تصدیق کر دی کہ فوج نے کوئی ثبو...  FAKE
# 11     12  گلگت بلتستان میں بھارتی میڈیا کی جعلی بغاوت بے...  FAKE
# 12     13  نواز شریف واقعی دنیا کے دوسرے کرپٹ ترین سیاستد...  FAKE
# 13     14  مسئلہ کشمیر پر وزیراعظم نواز شریف کے آج قوم سے...  FAKE
# 14     15    یونیسکو واقعی اسلام کو امن کا سرٹیفکیٹ دیتا ہے۔  FAKE

# %%
df_FakeNews = df_TrueFakeNews[df_TrueFakeNews["Label"] == "FAKE"]
df_FakeNews.head(15)
# Out:
#    Sr_No.                                         News_Items Label
# 0       1  ٹی ٹی پی نے پنجاب حکومت کے ہیلی کاپٹر کے عملے ...  FAKE
# 1       2          مارک زکربرگ سیاست میں آنے کا سوچ رہے ہیں۔  FAKE
# 2       3     فریدہ جلال نے اپنی موت کی افواہوں پر تنقید کی۔  FAKE
# 3       4  جعلی خبریں: پاپ اسٹار حدیقہ کیانی نے جعلی منشی...  FAKE
# 4       5  صنم ماروی نے میڈیا پر گردش کرنے والی زیادتی او...  FAKE
# 5       6  نواز شریف نے واقعی کرپشن کی وجہ سے ڈیووس میں ت...  FAKE
# 6       7  پی ایف اے کی ’آئرن لیڈی‘ عائشہ ممتاز کا ویڈیو-...  FAKE
# 7       8                   CPEC  کے بارے میں خطرناک افواہیں  FAKE
# 8       9  امریکہ نے القاعدہ کی جعلی ویڈیوز بنانے پر کروڑ...  FAKE
# 9      10  پاکستان کا جعلی پروگرام نشر کرنے پر بھارتی چین...  FAKE
# 10     11  بھارتی صحافی نے تصدیق کر دی کہ فوج نے کوئی ثبو...  FAKE
# 11     12  گلگت بلتستان میں بھارتی میڈیا کی جعلی بغاوت بے...  FAKE
# 12     13  نواز شریف واقعی دنیا کے دوسرے کرپٹ ترین سیاستد...  FAKE
# 13     14  مسئلہ کشمیر پر وزیراعظم نواز شریف کے آج قوم سے...  FAKE
# 14     15    یونیسکو واقعی اسلام کو امن کا سرٹیفکیٹ دیتا ہے۔  FAKE

# %%
df_RealNews= df_TrueFakeNews[df_TrueFakeNews["Label"] == "TRUE"]
df_RealNews.head(15)
# Out:
#      Sr_No.                                         News_Items Label
# 5054      1  دہلی میں جلد ہی 24×7 مال، تجارتی علاقوں میں کھ...  TRUE
# 5055      2  بی جے پی مسلسل ہاردک پٹیل کو ہراساں کر رہی ہے:...  TRUE
# 5056      3  کیرالہ اور پنجاب کے بعد مہاراشٹرا بھی سی اے اے...  TRUE
# 5057      4  AAP کے جگدیپ سنگھ نے دہلی انتخابات میں ٹکٹ نہ ...  TRUE
# 5058      5  یوپی کے سی ایم یوگی آدتیہ ناتھ کے قریبی ساتھی ...  TRUE
# 5059      6  مودی حکومت کے وزراء کشمیری سیاست دانوں سے مل س...  TRUE
# 5060      7  سی اے اے کی مخالفت کرنے والے دانشور شیطان اور ...  TRUE
# 5061      8  ہماچل پردیش کے سابق وزیر راجیو بندل کو ریاستی ...  TRUE
# 5062      9  بی جے پی نئی دہلی سیٹ سے اروند کیجریوال سے مقا...  TRUE
# 5063     10  بی جے پی اور پون کلیان نے اتحاد کا اعلان کیا، ...  TRUE
# 5064     11  سہراب گوٹھ میں پولیس اہلکاروں کو شہید کرنے وال...  TRUE
# 5065     12  کراچی: معاشی ماہرین اور بزنس کمیونٹی نے پاکستا...  TRUE
# 5066     13  ماہرین صحت نے بچوں کے لیے مصنوعی دودھ پربھاری ...  TRUE
# 5067     14  شمالی وزیرستان: سیکیورٹی فورسز اور دہشتگردوں م...  TRUE
# 5068     15  پاپ دنیا کے بادشاہ مائیکل جیکسن کی مشہور ٹوپی ...  TRUE

# %%
#Data Cleaning

# %%
df_FakeNews.isnull().sum()
# Out:
# Sr_No.        0
# News_Items    0
# Label         0
# dtype: int64

# %%
df_RealNews.isnull().sum()
# Out:
# Sr_No.        0
# News_Items    0
# Label         0
# dtype: int64

# %%
#To Drop some columns

# %%
if 'Sr_No.' in df_RealNews.columns:
  df_RealNews.drop(columns=["Sr_No."], inplace=True)

df_RealNews.head(15)
# Out:
# <ipython-input-423-030dcfbf54be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RealNews.drop(columns=["Sr_No."], inplace=True)
#                                              News_Items Label
# 5054  دہلی میں جلد ہی 24×7 مال، تجارتی علاقوں میں کھ...  TRUE
# 5055  بی جے پی مسلسل ہاردک پٹیل کو ہراساں کر رہی ہے:...  TRUE
# 5056  کیرالہ اور پنجاب کے بعد مہاراشٹرا بھی سی اے اے...  TRUE
# 5057  AAP کے جگدیپ سنگھ نے دہلی انتخابات میں ٹکٹ نہ ...  TRUE
# 5058  یوپی کے سی ایم یوگی آدتیہ ناتھ کے قریبی ساتھی ...  TRUE
# 5059  مودی حکومت کے وزراء کشمیری سیاست دانوں سے مل س...  TRUE
# 5060  سی اے اے کی مخالفت کرنے والے دانشور شیطان اور ...  TRUE
# 5061  ہماچل پردیش کے سابق وزیر راجیو بندل کو ریاستی ...  TRUE
# 5062  بی جے پی نئی دہلی سیٹ سے اروند کیجریوال سے مقا...  TRUE
# 5063  بی جے پی اور پون کلیان نے اتحاد کا اعلان کیا، ...  TRUE
# 5064  سہراب گوٹھ میں پولیس اہلکاروں کو شہید کرنے وال...  TRUE
# 5065  کراچی: معاشی ماہرین اور بزنس کمیونٹی نے پاکستا...  TRUE
# 5066  ماہرین صحت نے بچوں کے لیے مصنوعی دودھ پربھاری ...  TRUE
# 5067  شمالی وزیرستان: سیکیورٹی فورسز اور دہشتگردوں م...  TRUE
# 5068  پاپ دنیا کے بادشاہ مائیکل جیکسن کی مشہور ٹوپی ...  TRUE

# %%
if 'Sr_No.' in df_FakeNews.columns:
  df_FakeNews.drop(columns=["Sr_No."], inplace=True)

df_FakeNews.head(15)
# Out:
# <ipython-input-424-3c25f418c14e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FakeNews.drop(columns=["Sr_No."], inplace=True)
#                                            News_Items Label
# 0   ٹی ٹی پی نے پنجاب حکومت کے ہیلی کاپٹر کے عملے ...  FAKE
# 1           مارک زکربرگ سیاست میں آنے کا سوچ رہے ہیں۔  FAKE
# 2      فریدہ جلال نے اپنی موت کی افواہوں پر تنقید کی۔  FAKE
# 3   جعلی خبریں: پاپ اسٹار حدیقہ کیانی نے جعلی منشی...  FAKE
# 4   صنم ماروی نے میڈیا پر گردش کرنے والی زیادتی او...  FAKE
# 5   نواز شریف نے واقعی کرپشن کی وجہ سے ڈیووس میں ت...  FAKE
# 6   پی ایف اے کی ’آئرن لیڈی‘ عائشہ ممتاز کا ویڈیو-...  FAKE
# 7                    CPEC  کے بارے میں خطرناک افواہیں  FAKE
# 8   امریکہ نے القاعدہ کی جعلی ویڈیوز بنانے پر کروڑ...  FAKE
# 9   پاکستان کا جعلی پروگرام نشر کرنے پر بھارتی چین...  FAKE
# 10  بھارتی صحافی نے تصدیق کر دی کہ فوج نے کوئی ثبو...  FAKE
# 11  گلگت بلتستان میں بھارتی میڈیا کی جعلی بغاوت بے...  FAKE
# 12  نواز شریف واقعی دنیا کے دوسرے کرپٹ ترین سیاستد...  FAKE
# 13  مسئلہ کشمیر پر وزیراعظم نواز شریف کے آج قوم سے...  FAKE
# 14    یونیسکو واقعی اسلام کو امن کا سرٹیفکیٹ دیتا ہے۔  FAKE

# %%
#0 for fake news, and 1 for real news

df_FakeNews['class'] = 0
df_FakeNews.head(15)
# Out:
# <ipython-input-425-2ee2b64f980b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FakeNews['class'] = 0
#                                            News_Items Label  class
# 0   ٹی ٹی پی نے پنجاب حکومت کے ہیلی کاپٹر کے عملے ...  FAKE      0
# 1           مارک زکربرگ سیاست میں آنے کا سوچ رہے ہیں۔  FAKE      0
# 2      فریدہ جلال نے اپنی موت کی افواہوں پر تنقید کی۔  FAKE      0
# 3   جعلی خبریں: پاپ اسٹار حدیقہ کیانی نے جعلی منشی...  FAKE      0
# 4   صنم ماروی نے میڈیا پر گردش کرنے والی زیادتی او...  FAKE      0
# 5   نواز شریف نے واقعی کرپشن کی وجہ سے ڈیووس میں ت...  FAKE      0
# 6   پی ایف اے کی ’آئرن لیڈی‘ عائشہ ممتاز کا ویڈیو-...  FAKE      0
# 7                    CPEC  کے بارے میں خطرناک افواہیں  FAKE      0
# 8   امریکہ نے القاعدہ کی جعلی ویڈیوز بنانے پر کروڑ...  FAKE      0
# 9   پاکستان کا جعلی پروگرام نشر کرنے پر بھارتی چین...  FAKE      0
# 10  بھارتی صحافی نے تصدیق کر دی کہ فوج نے کوئی ثبو...  FAKE      0
# 11  گلگت بلتستان میں بھارتی میڈیا کی جعلی بغاوت بے...  FAKE      0
# 12  نواز شریف واقعی دنیا کے دوسرے کرپٹ ترین سیاستد...  FAKE      0
# 13  مسئلہ کشمیر پر وزیراعظم نواز شریف کے آج قوم سے...  FAKE      0
# 14    یونیسکو واقعی اسلام کو امن کا سرٹیفکیٹ دیتا ہے۔  FAKE      0

# %%
df_RealNews['class'] = 1
df_RealNews.head(15)
# Out:
# <ipython-input-426-e82ed5c29ea7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RealNews['class'] = 1
#                                              News_Items Label  class
# 5054  دہلی میں جلد ہی 24×7 مال، تجارتی علاقوں میں کھ...  TRUE      1
# 5055  بی جے پی مسلسل ہاردک پٹیل کو ہراساں کر رہی ہے:...  TRUE      1
# 5056  کیرالہ اور پنجاب کے بعد مہاراشٹرا بھی سی اے اے...  TRUE      1
# 5057  AAP کے جگدیپ سنگھ نے دہلی انتخابات میں ٹکٹ نہ ...  TRUE      1
# 5058  یوپی کے سی ایم یوگی آدتیہ ناتھ کے قریبی ساتھی ...  TRUE      1
# 5059  مودی حکومت کے وزراء کشمیری سیاست دانوں سے مل س...  TRUE      1
# 5060  سی اے اے کی مخالفت کرنے والے دانشور شیطان اور ...  TRUE      1
# 5061  ہماچل پردیش کے سابق وزیر راجیو بندل کو ریاستی ...  TRUE      1
# 5062  بی جے پی نئی دہلی سیٹ سے اروند کیجریوال سے مقا...  TRUE      1
# 5063  بی جے پی اور پون کلیان نے اتحاد کا اعلان کیا، ...  TRUE      1
# 5064  سہراب گوٹھ میں پولیس اہلکاروں کو شہید کرنے وال...  TRUE      1
# 5065  کراچی: معاشی ماہرین اور بزنس کمیونٹی نے پاکستا...  TRUE      1
# 5066  ماہرین صحت نے بچوں کے لیے مصنوعی دودھ پربھاری ...  TRUE      1
# 5067  شمالی وزیرستان: سیکیورٹی فورسز اور دہشتگردوں م...  TRUE      1
# 5068  پاپ دنیا کے بادشاہ مائیکل جیکسن کی مشہور ٹوپی ...  TRUE      1

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
plt.figure(figsize=(10, 5))
plt.title('Distribution of Fake News and Real News', size=15)

plt.bar('Fake News', len(df_FakeNews), color='orange')
plt.bar('Real News', len(df_RealNews), color='green')

#X-Axis
plt.xlabel('News Type', size=15)
#Y-Axis
plt.ylabel('# of News Articles', size=15)
# Out:
# Text(0, 0.5, '# of News Articles')

# %%
#After Cleaning combined the datasets
news_df = pd.concat([df_RealNews, df_FakeNews], ignore_index=True, sort=False)
df_FirstLast = pd.concat([news_df.head(10) ,news_df.tail(10)])
df_FirstLast
# Out:
#                                               News_Items Label  class
# 0      دہلی میں جلد ہی 24×7 مال، تجارتی علاقوں میں کھ...  TRUE      1
# 1      بی جے پی مسلسل ہاردک پٹیل کو ہراساں کر رہی ہے:...  TRUE      1
# 2      کیرالہ اور پنجاب کے بعد مہاراشٹرا بھی سی اے اے...  TRUE      1
# 3      AAP کے جگدیپ سنگھ نے دہلی انتخابات میں ٹکٹ نہ ...  TRUE      1
# 4      یوپی کے سی ایم یوگی آدتیہ ناتھ کے قریبی ساتھی ...  TRUE      1
# 5      مودی حکومت کے وزراء کشمیری سیاست دانوں سے مل س...  TRUE      1
# 6      سی اے اے کی مخالفت کرنے والے دانشور شیطان اور ...  TRUE      1
# 7      ہماچل پردیش کے سابق وزیر راجیو بندل کو ریاستی ...  TRUE      1
# 8      بی جے پی نئی دہلی سیٹ سے اروند کیجریوال سے مقا...  TRUE      1
# 9      بی جے پی اور پون کلیان نے اتحاد کا اعلان کیا، ...  TRUE      1
# 10026   35YO سائنسدان خوشبھو مرزا کو ISRO کے ڈائریکٹر...  FAKE      0
# 10027  نہیں، ہندوستانی فضائیہ کا جیٹ نیپالی افواج نے ...  FAKE      0
# 10028   ویڈیو کا دعویٰ کرنے والا اٹلی نے دریافت کیا ک...  FAKE      0
# 10029   وائرل ویڈیو جس میں بنگلورو کے وکٹوریہ اسپتال ...  FAKE      0
# 10030   کولمبیا سے COVID-19 کی موک ڈرل کی ویڈیو شیئر ...  FAKE      0
# 10031  اس پادری پر بنگلہ دیشیوں یا مسلمانوں نے حملہ ن...  FAKE      0
# 10032   طوطوں کی پرانی تصویر جو اناج پر کھانا کھلا رہ...  FAKE      0
# 10033   رتن ٹاٹا نے ممبئی کے نوجوان میں 50 فیصد حصص ن...  FAKE      0
# 10034  سماجی دوری پر بحث کرنے والے مسافروں کی ویڈیو ن...  FAKE      0
# 10035  COVID-19 سے صحت یاب ہونے کے بعد جشن منانے کے د...  FAKE      0

# %%
all_words = ' '.join([text for text in news_df.News_Items])
len(all_words)
# Out:
# 3535603

# %%
import json
import requests

# Load the JSON file from the GitHub URL
url = "https://raw.githubusercontent.com/Jawad-repo/Model_Training_Multilingual_Fake_News_Detection/main/stopwords-ur.json"
response = requests.get(url)
stopwords_json = response.json()

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Manually define Urdu stop words
urdu_stop_words = {"تھا","ہیں","ہے","کیا","آپکے", "آپکا", "آپکو", "ہاں", "ہوں", "ہوگا", "ہوگی", "ہوگے", "ت", "و", "کہیں", "وغیرہ",
    "ا", "ان", "انکے", "انکی", "انکو", "انہوں", "انہیں", "اور", "ایسے", "ب", "بہت", "تاکہ", "تھا",
    "تھی", "تھے", "تھیں", "جب", "جبکہ", "جو", "حالانکہ", "خواہ", "خود", "دو", "دی", "دیا", "دیتے",
    "دیکھا", "دیکھو", "دیں", "رہا", "رہی", "رہے", "رہیں", "رہے", "ساتھ", "سب", "سبھی", "سو", "سے",
    "شاید", "صرف", "ضرور", "ضرورت", "ضروری", "طرح", "طرف", "طور", "علاوہ", "عین", "غیر", "لیکن", "مگر",
    "میں", "نہ", "نہیں", "والا", "والوں", "والی", "والیں", "والے", "وغیرہ", "وہ", "وہاں", "وہی", "وہیں",
    "پ", "پر", "پوری", "پھر", "چاہئے", "چاہتے", "چاہیے", "چاہیں", "چونکہ", "چکی", "چکے", "چکیں", "چکے",
    "چنانچہ", "چند", "چکی", "چکے", "کر", "کرتا", "کرتی", "کرتے", "کرتی", "کرتے", "کرنا", "کرنے", "کرنی",
    "کرنے", "کرنی", "کرنے", "کرنیں", "کرنے", "کرنیں", "کرنے", "کرنیں", "کرے", "کریں", "کم", "کس", "کسی",
    "کسے", "کی", "کیسے", "کیونکہ", "کے", "گئی", "گئے", "گئیں", "گئے", "گا", "گائیں", "گرم", "گریبان", "گریبانیں",
    "گی", "گیا", "گیں", "ہر", "ہم", "ہمیں", "ہو", "ہوئی", "ہوئیں", "ہوئے", "ہوئیں", "ہوتا", "ہوتی", "ہوتے",
    "ہوتی", "ہوتے", "ہونا", "ہونگے", "ہونگی", "ہونگے", "ہونی", "ہونیں", "ہونے", "ہونیں", "ہوں", "ہوگا", "ہوگی",
    "ہوگا", "ہوگی", "ہوگے", "ہوگیں", "یا", "یہ", "یہاں", "یہی", "یہیں", "یہے","اب","ابھی","اپنا","اپنے","اپنی",
    "اٹھا","اس","اسے","اسی","اگر","ان","انہوں","انہی","انہیں","انھیں","او","اور","اے","ایسا","ایسے","ایسی","ایک",
    "آ","آپ","آتا","آتے","آتی","آگے","آنا","آنے","آنی","آئے","آئی","آئیں","آیا","با","بڑا","بڑے","بڑی","بعد","بعض",
    "بلکہ","بہت","بھی","بے","پاس","پر","پہلے","پھر","تا","تاکہ","تب","تجھ","تجھے","تک","تم","تمام","تمہارا","تمہارے",
    "تمھارے","تمہاری","تمہیں","تمھیں","تھا","تھے","تھی","تھیں","تو","تیری","تیرے","جا","جاتا","جاتی","جاتے","جاتی","جانے",
    "جانی","جاؤ","جائے","جائیں","جب","جس","جن","جنہوں","جنہیں","جو","جیسا","جیسے","جیسی","جیسوں","چاہیئے","چلا","چاہے","چونکہ",
    "حالاں","حالانکہ","دو","دونوں","دوں","دے","دی","دیا","دیں","دیے","دیتا","دیتے","دیتی","دینا","دینے","دینی","دیئے","ڈالا","ڈالنا",
    "ڈالنے","ڈالنی","ڈالے","ڈالی","ذرا","رکھا","رکھتا","رکھتے","رکھتی","رکھنا","رکھنے","رکھنی","رکھے","رکھی","رہ","رہا","رہتا","رہتے",
    "رہتی","رہنا","رہنے","رہنی","رہو","رہے","رہی","رہیں","زیادہ","سا","سامنے","سب","سکتا","سو","سے","سی","شاید","صرف","طرح","طرف","عین",
    "کا","کبھی","کچھ","کہہ","کر","کرتا","کرتے","کرتی","کرنا","کرنے","کرو","کروں","کرے","کریں","کس","کسے","کسی","کہ","کہا","کہے","کو","کون",
    "کوئی","کے","کی","کیا","کیسے","کیوں","کیونکہ","کیے","کئے","گا","گویا","گے","گی","گیا","گئے","گئی","لا","لاتا","لاتے","لاتی","لانا","لانے","لانی",
    "لایا","لائے","لائی","لگا","لگے","لگی","لگیں","لو","لے","لی","لیا","لیتا","لیتے","لیتی","لیکن","لیں","لیے","لئے","مجھ","مجھے","مگر","میرا",
    "میرے","میری","میں","نا","نہ","نہایت","نہیں","نے","ہاں","ہر","ہم","ہمارا","ہمارے","ہماری","ہو","ہوا","ہوتا","ہوتے","ہوتی","ہوتیں","ہوں",
    "ہونا","ہونگے","ہونے","ہونی","ہوئے","ہوئی","ہوئیں","ہے","ہی","ہیں","و","والا","والوں","والے","والی","وہ","وہاں","وہی","وہیں","یا","یعنی",
    "یہ","یہاں","یہی","یہیں"
}

# Initialize a WordNetLemmatizer object
lemmatizer = WordNetLemmatizer()

# Tokenize the text
tokens = word_tokenize(all_words)

# Remove stop words and lemmatize tokens
cleaned_tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in urdu_stop_words]

# Join the tokens back into text
cleaned_text = ' '.join(cleaned_tokens)

all_words=cleaned_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
 len(all_words)
# Out:
# 2212412

# %%
# Word cloud for fake news
from wordcloud import WordCloud

# Font_Url = (r'https://github.com/Jawad-repo/Model_Training_Multilingual_Fake_News_Detection/blob/main/NotoNaskhArabic-Regular.ttf')

wordcloud = WordCloud(width= 800, height= 500,
                          font_path='NotoNaskhArabic-Regular.ttf',
                          max_font_size = 210,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Split into training and testing
from sklearn.model_selection import train_test_split

# %%
features = news_df['News_Items']
targets = news_df['class']

X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.20, random_state=18)

# %%
X_test
# Out:
# 5044    وزیراعلیٰ بزدار کا پروٹوکول پنجاب کے اسپتال می...
# 2983    نیوزی لینڈ کے کرکٹر مارٹن گپٹل نے ہفتے کے روز ...
# 6989    بھارت اور آسٹریلیا کے درمیان حال ہی میں ٹیسٹ س...
# 3457    \tقومی اسمبلی کی کارروائی کے دوران شہباز شریف ...
# 6438    سوشل میڈیا پر بچوں کی ایک ویڈیو وائرل ہو رہی ہ...
#                               ...
# 3502    \tکامیڈین یاسر حسین کے ایک بیان پر انھیں ارطغر...
# 4406    مانسون اجلاس سے 4 دن پہلے ہماچل کے وزیر کا کوو...
# 4518    اتراکھنڈ میں 15 گھنٹے ریسکیو: ITBP کی ٹیم زخمی...
# 9803     ڈبلیو ایچ او نے کوویڈ 19 کی غیر علامتی منتقلی...
# 6060    ہندوستانی اداکار اپنے خاندان کے ساتھ پاکستان م...
# Name: News_Items, Length: 2008, dtype: object

# %%
X_test
# Out:
# 5044    وزیراعلیٰ بزدار کا پروٹوکول پنجاب کے اسپتال می...
# 2983    نیوزی لینڈ کے کرکٹر مارٹن گپٹل نے ہفتے کے روز ...
# 6989    بھارت اور آسٹریلیا کے درمیان حال ہی میں ٹیسٹ س...
# 3457    \tقومی اسمبلی کی کارروائی کے دوران شہباز شریف ...
# 6438    سوشل میڈیا پر بچوں کی ایک ویڈیو وائرل ہو رہی ہ...
#                               ...
# 3502    \tکامیڈین یاسر حسین کے ایک بیان پر انھیں ارطغر...
# 4406    مانسون اجلاس سے 4 دن پہلے ہماچل کے وزیر کا کوو...
# 4518    اتراکھنڈ میں 15 گھنٹے ریسکیو: ITBP کی ٹیم زخمی...
# 9803     ڈبلیو ایچ او نے کوویڈ 19 کی غیر علامتی منتقلی...
# 6060    ہندوستانی اداکار اپنے خاندان کے ساتھ پاکستان م...
# Name: News_Items, Length: 2008, dtype: object

# %%
import re

# %%
def normalize(data):
    normalized = []
    for i in data:
        i = i.lower()
        # get rid of urls
        i = re.sub('https?://\S+|www\.\S+', '', i)
        # get rid of non words and extra spaces
        i = re.sub('\\W', ' ', i)
        i = re.sub('\n', '', i)
        i = re.sub(' +', ' ', i)
        i = re.sub('^ ', '', i)
        i = re.sub(' $', '', i)
        normalized.append(i)
    return normalized

X_train = normalize(X_train)
X_test = normalize(X_test)

# %%
y_test.head(10)
# Out:
# 5044    0
# 2983    1
# 6989    0
# 3457    1
# 6438    0
# 4393    1
# 367     1
# 8435    0
# 5702    0
# 7124    0
# Name: class, dtype: int64

# %%
max_vocab = 10000
tokenizer = Tokenizer(num_words=max_vocab)
tokenizer.fit_on_texts(X_train)

# %%
# tokenize the text into vectors
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, padding='post', maxlen=256)
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, padding='post', maxlen=256)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(max_vocab, 128),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 128)         1280000
#
#  bidirectional_4 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 32)                18560
#  onal)
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1399553 (5.34 MB)
# Trainable params: 1399553 (5.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=10,validation_split=0.1, batch_size=30, shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 241/241 [==============================] - 142s 554ms/step - loss: 0.6714 - accuracy: 0.5257 - val_loss: 0.6253 - val_accuracy: 0.6750
# Epoch 2/10
# 241/241 [==============================] - 130s 540ms/step - loss: 0.5061 - accuracy: 0.7480 - val_loss: 0.3820 - val_accuracy: 0.8194
# Epoch 3/10
# 241/241 [==============================] - 137s 567ms/step - loss: 0.2799 - accuracy: 0.8907 - val_loss: 0.2897 - val_accuracy: 0.8730
# Epoch 4/10
# 241/241 [==============================] - 129s 535ms/step - loss: 0.1766 - accuracy: 0.9379 - val_loss: 0.2708 - val_accuracy: 0.8867
# Epoch 5/10
# 241/241 [==============================] - 129s 538ms/step - loss: 0.1116 - accuracy: 0.9684 - val_loss: 0.2957 - val_accuracy: 0.8879
# Epoch 6/10
# 241/241 [==============================] - 127s 526ms/step - loss: 0.0719 - accuracy: 0.9808 - val_loss: 0.3077 - val_accuracy: 0.8941

# %%
history_dict = history.history

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = history.epoch

plt.figure(figsize=(12,9))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss', size=20)
plt.xlabel('Epochs', size=20)
plt.ylabel('Loss', size=20)
plt.legend(prop={'size': 20})
plt.show()

plt.figure(figsize=(12,9))
plt.plot(epochs, acc, 'g', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy', size=20)
plt.xlabel('Epochs', size=20)
plt.ylabel('Accuracy', size=20)
plt.legend(prop={'size': 20})
plt.ylim((0.5,1))
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 8s 131ms/step - loss: 0.2648 - accuracy: 0.8904
# [0.26477959752082825, 0.8904382586479187]

# %%
pred = model.predict(X_test)

binary_predictions = []

for i in pred:
    if i >= 0.5:
        binary_predictions.append(1)
    else:
        binary_predictions.append(0)
# Out:
# 63/63 [==============================] - 10s 127ms/step

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

# %%
print('Accuracy on testing set:', accuracy_score(binary_predictions, y_test))
print('Precision on testing set:', precision_score(binary_predictions, y_test))
print('Recall on testing set:', recall_score(binary_predictions, y_test))
# Out:
# Accuracy on testing set: 0.8904382470119522
# Precision on testing set: 0.883629191321499
# Recall on testing set: 0.8977955911823647

# %%
import seaborn as sns

# %%
matrix = confusion_matrix(binary_predictions, y_test, normalize='all')
plt.figure(figsize=(16, 10))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax)

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix', size=20)
ax.xaxis.set_ticklabels([0,1], size=15)
ax.yaxis.set_ticklabels([0,1], size=15)
# Out:
# [Text(0, 0.5, '0'), Text(0, 1.5, '1')]
